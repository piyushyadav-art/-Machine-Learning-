# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushyadav-art/-Machine-Learning-/blob/main/Precision%2C_Recall_and_F1_Score_Python_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
heart_data = pd.read_csv('/content/heart.csv')

# %%
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']

# %%
print(X)
print(Y)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model = LogisticRegression(max_iter = 1000)

# %%
model.fit(X_train, Y_train )
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train,X_train_prediction)
print(training_data_accuracy)
# Out:
# 0.8553719008264463

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test,X_test_prediction)
print(test_data_accuracy)
# Out:
# 0.8032786885245902

# %%
print('Accuracy on Test data:',round(test_data_accuracy*100,2),'%')
# Out:
# Accuracy on Test data: 80.33 %

# %% [markdown]
# **Precision**

# %%
from sklearn.metrics import precision_score

# %%
# precision for training data predictions
precision_train = precision_score(Y_train, X_train_prediction)
print('Precision for training data:', round(precision_train*100,2),'%')
# Out:
# Precision for training data: 82.99 %

# %%
# precision for test data predictions
precision_test = precision_score(Y_test, X_test_prediction)
print('Precision for test data:', round(precision_test*100,2),'%')
# Out:
# Precision for test data: 81.82 %

# %% [markdown]
# **Recall  **

# %%
from sklearn.metrics import recall_score

# %%
# precision for training data predictions
recall_train = recall_score(Y_train, X_train_prediction)
print('Recall for training data:', round(recall_train*100,2),'%')
# Out:
# Recall for training data: 92.42 %

# %%
# precision for test data predictio
recall_test = recall_score(Y_test, X_test_prediction)
print('Recall for test data:', round(recall_test*100,2),'%')
# Out:
# Recall for test data: 81.82 %

# %% [markdown]
# **F1 Score**

# %%
from sklearn.metrics import f1_score

# %%
# F1 score for training data predictions
f1_score_train = f1_score(Y_train, X_train_prediction)
print('F1 score for training data:', round(f1_score_train*100,2),'%')
# Out:
# F1 score for training data: 87.46 %

# %%
# F1 score for test data predictio
f1_score_test = f1_score(Y_test, X_test_prediction)
print('F1 score for test data:', round(f1_score_test*100,2),'%')
# Out:
# F1 score for test data: 81.82 %

# %% [markdown]
# Precision,Recall & F1 Score - function

# %%
def precision_recall_f1_score(true_labels, pred_labels):
  precision_value = precision_score(true_labels, pred_labels)
  recall_value = recall_score(true_labels, pred_labels)
  f1_score_value = f1_score(true_labels, pred_labels)

  print('Precision:', round(precision_value*100,2),'%')
  print('Recall:', round(recall_value*100,2),'%')
  print('F1 Score:', round(f1_score_value*100,2),'%')

# %%
# classification metrics for training data
precision_recall_f1_score(Y_train, X_train_prediction)
# Out:
# Precision: 82.99 %
# Recall: 92.42 %
# F1 Score: 87.46 %

# %%
# classification metrics for test data
precision_recall_f1_score(Y_test, X_test_prediction)
# Out:
# Precision: 81.82 %
# Recall: 81.82 %
# F1 Score: 81.82 %

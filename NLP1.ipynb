# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushyadav-art/-Machine-Learning-/blob/main/NLP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **What is NLP Pipeline ?**

# %% [markdown]
# NLP is a set of steps followed to build an end to end softwre.
# NLP software consist of The following steps :
# 1. Data Acquisition
# 2. Text Preparation
# (Text Cleanup,Basic Preprocessing, Advance Preprocessing)
# 3. Feature Engineering
# 4. Modelling(Model Building, Evaluation)
# 5. Deployment
# (Deployment, Monitoring, Model Update)

# %% [markdown]
# **Text Preparation**

# %% [markdown]
# *Text Cleanup:*

# %% [markdown]
# #Removing HTML Tags

# %%
sample_text ='<header ><div class="Top_name"><b>Tagore Library</b></div><div class="header1">Home</div><div class="header2">About</div><div class="header3">Contact</div></header>'

# %%
sample_text
# Out:
# '<header ><div class="Top_name"><b>Tagore Library</b></div><div class="header1">Home</div><div class="header2">About</div><div class="header3">Contact</div></header>'

# %%
import re
def striphtml(data):
  p = re.compile(r'<.*?>') #'<.*?>'
  return p.sub('',data)

# %%
striphtml(sample_text)
# Out:
# 'Tagore LibraryHomeAboutContact'

# %% [markdown]
# #Removing URL:

# %%
def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'',text)

# %%
text1 = 'Cheak out my notebook https://www.kangle.com/campusx/notebook8223fclabb'
text1 = 'Cheak out my notebook http://www.kangle.com/campusx/notebook8223fclabb'
text3 = 'Cheak out my notebook www.kangle.com/campusx/notebook8223fclabb'
text4 = 'Cheak out my notebook kangle.com/campusx/notebook8223fclabb'

# %%
import re

def remove_url(text):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'',text)

# Now call The function
remove_url(text1)
# Out:
# 'Cheak out my notebook '

# %% [markdown]
# #Removing Punctuation

# %%
import string
# string.time # This line is incorrect and should be removed or corrected if time module is needed separately.
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
exclude = string.punctuation

# %%
def remove_punc(text):
  for char in exclude:
    text = text.replace(char,'')
  return text

# %%
text = 'string. With. Punctuation?'

# %%
import time

start = time.time()
print(remove_punc(text))
time_taken = time.time()-start
print(f'Time taken is {time_taken*90000}')
# Out:
# string With Punctuation
# Time taken is 42.80805587768555

# %% [markdown]
# Second Methods

# %%
def remove_punc1(text):
  return text.translate(str.maketrans('','',exclude))

# %%
import time
import string

def remove_punc1(text):
  exclude = string.punctuation
  return text.translate(str.maketrans('','',exclude))

start = time.time()
removed_text = remove_punc1(text)
time2 = time.time()-start
print(f'Time taken is {time2*90000}')
# Out:
# Time taken is 6.222724914550781

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/test.csv.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1704912926.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('/content/test.csv.zip')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df.sample(5)

# %%
df.shape

# %%
import string
exclude = string.punctuation

# %%
exclude = string.punctuation

# %%
 def remove_punc1(text):
  return text.translate(str.maketrans('','',exclude))

# %%
df['tweet']= df['tweet'].apply(remove_punc1)

# %%
df

# %% [markdown]
# #Chat word treatment

# %%
chat_words = {
    'AFAIK':'As Far As I Know',
    'AFK':'Away From Keyboard',
    'ASAP':'As Soon As Possible',
    'ATK':'At The Keyboard',
    'ATM':'At The Moment',
    'A3':'Anytime, Anywhere, Anyplace',
    'BAK':'Back At Keyboard',
    'BBL':'Be Back Later',
    'BBS':'Be Back Soon',
    'BFN':'Bye For Now',
    'B4N':'Bye For Now',
    'BRB':'Be Right Back',
    'BRT':'Be Right There',
    'BTW':'By The Way',
    'B4':'Before',
    'B4N':'Bye For Now',
    'CU':'See You',
    'CUL8R':'See You Later',
    'CYA':'See You',
    'FAQ':'Frequently Asked Questions',
    'FC':'Fingers Crossed',
    'FWIW':'For What It\'s Worth',
    'FYI':'For Your Information',
    'GAL':'Get A Life',
    'GG':'Good Game',
    'GN':'Good Night',
    'GMTA':'Great Minds Think Alike',
    'GR8':'Great!',
    'G9':'Genius',
    'IC':'I See',
    'ICQ':'I Seek you',
    'ILU':'ILU: I Love You',
    'IMHO':'In My Humble Opinion',
    'IMO':'In My Opinion',
    'IOW':'In OTher Words',
    'IRL':'In Real Life',
    'KISS':'Keep It Simple, Stupid',
    'LDR':'Long Distance Relationship',
    'LMAO':'Laugh My Ass Off',
    'LOL':'Laughing Out Loud',
    'LTNS':'Long Time No See',
    'L8R':'Later',
    'MTE':'My Thoughts Exactly',
    'M8':'Mate',
    'NRN':'No Reply Necessary',
    'OIC':'Oh I See',
    'OMG':'Oh My God',
    'PITA':'Pain In The Ass',
    'PRT':'Party',
    'PRW':'Parents Are Watching',
    'QPSA':'Que Pasa?',
    'ROFL':'Rolling On The Floor Laughing',
    'ROFLOL':'Rolling On The Floor Laughing Out Loud',
    'ROTFLMAO':'Rolling On The Floor Laughing My Ass Off',
    'SK8':'Skate',
    'STATS':'Your sex and age',
    'ASL':'Age, Sex, Location',
    'THX':'Thank You',
    'TTFN':'Ta-Ta For Now!',
    'TTYL':'Talk To You Later',
    'U':'You',
    'U2':'You Too',
    'U4E':'Yours For Ever',
    'WB':'Welcome Back',
    'WTF':'What The F**K',
    'WTG':'Way To Go!',
    'WUF':'Where Are You From?',
    'W8':'Wait...',
    '7K':'Sick:-D Laugher'
}

# %%
chat_words
# Out:
# {'AFAIK': 'As Far As I Know',
#  'AFK': 'Away From Keyboard',
#  'ASAP': 'As Soon As Possible',
#  'ATK': 'At The Keyboard',
#  'ATM': 'At The Moment',
#  'A3': 'Anytime, Anywhere, Anyplace',
#  'BAK': 'Back At Keyboard',
#  'BBL': 'Be Back Later',
#  'BBS': 'Be Back Soon',
#  'BFN': 'Bye For Now',
#  'B4N': 'Bye For Now',
#  'BRB': 'Be Right Back',
#  'BRT': 'Be Right There',
#  'BTW': 'By The Way',
#  'B4': 'Before',
#  'CU': 'See You',
#  'CUL8R': 'See You Later',
#  'CYA': 'See You',
#  'FAQ': 'Frequently Asked Questions',
#  'FC': 'Fingers Crossed',
#  'FWIW': "For What It's Worth",
#  'FYI': 'For Your Information',
#  'GAL': 'Get A Life',
#  'GG': 'Good Game',
#  'GN': 'Good Night',
#  'GMTA': 'Great Minds Think Alike',
#  'GR8': 'Great!',
#  'G9': 'Genius',
#  'IC': 'I See',
#  'ICQ': 'I Seek you',
#  'ILU': 'ILU: I Love You',
#  'IMHO': 'In My Humble Opinion',
#  'IMO': 'In My Opinion',
#  'IOW': 'In Other Words',
#  'IRL': 'In Real Life',
# ...

# %%
def chat_conversion(text):
  new_text = []
  for w in text.split():
    if w.upper() in chat_words:
      new_text.append(chat_words[w.upper()])
    else:
      new_text.append(w)
  return " ".join(new_text)

# %%
chat_conversion('IMHO he is The best')
# Out:
# 'In My Humble Opinion he is the best'

# %%
chat_conversion('FYI delhi is The captial of India')
# Out:
# 'For Your Information delhi is the captial of India'

# %% [markdown]
# #Checking Spell mistake

# %%
incorrect_text = 'ceertain conditionas duriing seveal ggenerations aree moodified in The saame maner.'

# %%
from textblob import TextBlob
textBlb = TextBlob(incorrect_text)
textBlb.correct()
# Out:
# TextBlob("certain conditions during several generations are modified in the same manner.")

# %% [markdown]
# #Removing Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
stopwords.words('spanish')
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosotros',
# ...

# %%
def remove_stopwords(text):
  new_text = []
  for word in text.split():
    if word in stopwords.words('english'):
      new_text.append('')
    else:
      new_text.append(word)
  x = new_text[:]
  new_text.clear()
  return " ".join(x)

# %%
remove_stopwords('MoTher Teresa was an Albanian-Indian nun who dedicated her life to serving The poor and sick, founding The Missionaries of Charity in Kolkata, India. Known for her compassion and simple lifestyle, she provided food, shelter, and comfort to The destitute and received international recognition for her humanitarian work, including The Nobel Peace Prize and Indias Bharat Ratna. In 2016, she was canonized as Saint Teresa of Calcutta')
# Out:
# 'Mother Teresa   Albanian-Indian nun  dedicated  life  serving  poor  sick, founding  Missionaries  Charity  Kolkata, India. Known   compassion  simple lifestyle,  provided food, shelter,  comfort   destitute  received international recognition   humanitarian work, including  Nobel Peace Prize  Indias Bharat Ratna. In 2016,   canonized  Saint Teresa  Calcutta'

# %% [markdown]
# #Handling Emoji

# %%
import re
def remove_emoji(text):
  emoji_pattern = re.compile("["
                         "\U0001F600-\U0001F64F"  # Emoticons
                         "\U0001F300-\U0001F5FF"  # Symbols & pictographs
                         "\U0001F680-\U0001F6FF"  # Transport & map symbols
                         "\U0001F1E0-\U0001F1FF"  # Flags
                         "\U00002700-\U000027BF"  # Dingbats
                         "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                         "\U00002600-\U000026FF"  # Miscellaneous Symbols
                         "]+", flags=re.UNICODE)
  return emoji_pattern.sub(r'',text)

# %%
remove_emoji('Loved The movie.It was 😘😘')
# Out:
# 'Loved the movie.It was '

# %%
remove_emoji('Lmao 😂😂')
# Out:
# 'Lmao '

# %%
# !pip install emoji

# %%
import emoji
print(emoji.demojize('Python is 🔥'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2866304923.py in <cell line: 0>()
#       1 import emoji
# ----> 2 print(emoji.demolize('Python is 🔥'))
#
# AttributeError: module 'emoji' has no attribute 'demolize'

# %% [markdown]
# #Unicode Normalization

# %%
emoji_text = 'First , we established subjects. I was 😊, and I could use it to represent "me" in sentences. For example, 😊💕1️⃣could mean "I am running to work". '

# %%
emoji_text

# %%
emoji_text.encode('utf-8')

# %% [markdown]
# #Tokenization

# %% [markdown]
# 1. Used The split function

# %%
# word tokenization
sent1 = 'I am going to delhi'
sent1.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi']

# %%
# Sentence tokenization
sent2 = 'I am going to delhi. I will stay There for 3 days. Let\'s hope The trip to be great'
sent2.split('.')
# Out:
# ['I am going to delhi',
#  ' I will stay there for 3 days',
#  " Let's hope the trip to be great"]

# %%
# .Problem with split function
sent3 = 'I am going to delhi!'
sent3.split()
# Out:
# ['I', 'am', 'going', 'to', 'delhi!']

# %% [markdown]
# 2. Regular Expression

# %%
import re
sent3 = 'I am going to delhi!'
tokens = re.findall("[\w']+",sent3)
tokens
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-1372067809.py:3: SyntaxWarning: invalid escape sequence '\w'
#   tokens = re.findall("[\w']+",sent3)
# ['I', 'am', 'going', 'to', 'delhi']

# %%
text = 'lorem Ipsum is simply dummy text of The printing and typesetting industry? Lorem Ipsum has been The industry\'s standard dummy text ever since The 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also The leap into electronic typesetting, remaining essentially unchanged. It was popularised in The 1960s with The release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker.'
sentences = re.compile('[.!?] ').split(text)
sentences
# Out:
# ['lorem Ipsum is simply dummy text of the printing and typesetting industry',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book",
#  'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged',
#  'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker.']

# %% [markdown]
# 3. NLTK

# %%
# import nltk
# nltk.download('punkt')

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
sent1 = ' I am going to visit delhi!'
word_tokenize(sent1)
# Out:
# ['I', 'am', 'going', 'to', 'visit', 'delhi', '!']

# %%
text = 'lorem Ipsum is simply dummy text of The printing and typesetting industry? Lorem Ipsum has been The industry\'s standard dummy text ever since The 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also The leap into electronic typesetting, remaining essentially unchanged. It was popularised in The 1960s with The release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker.'
sent_tokenize(text)
# Out:
# ['lorem Ipsum is simply dummy text of the printing and typesetting industry?',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.",
#  'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.',
#  'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker.']

# %%
word_tokenize(text)
# Out:
# ['lorem',
#  'Ipsum',
#  'is',
#  'simply',
#  'dummy',
#  'text',
#  'of',
#  'the',
#  'printing',
#  'and',
#  'typesetting',
#  'industry',
#  '?',
#  'Lorem',
#  'Ipsum',
#  'has',
#  'been',
#  'the',
#  'industry',
#  "'s",
#  'standard',
#  'dummy',
#  'text',
#  'ever',
#  'since',
#  'the',
#  '1500s',
#  ',',
#  'when',
#  'an',
#  'unknown',
#  'printer',
#  'took',
#  'a',
#  'galley',
#  'of',
#  'type',
#  'and',
#  'scrambled',
#  'it',
#  'to',
#  'make',
#  'a',
#  'type',
#  'specimen',
#  'book',
#  '.',
#  'It',
#  'has',
#  'survived',
#  'not',
#  'only',
#  'five',
#  'centuries',
#  ',',
#  'but',
#  'also',
#  'the',
#  'leap',
#  'into',
#  'electronic',
#  'typesetting',
#  ',',
#  'remaining',
#  'essentially',
#  'unchanged',
#  '.',
#  'It',
#  'was',
#  'popularised',
#  'in',
#  'the',
#  '1960s',
#  'with',
#  'the',
#  'release',
#  'of',
#  'Letraset',
#  'sheets',
#  'containing',
#  'Lorem',
#  'Ipsum',
#  'passages',
#  ',',
#  'and',
# ...

# %%
sent5 = 'I have a ph.d in A.I'
sent6 = 'We\'re here to help! mail us john.mclean@examplepetstore.comcom'
sent7 = 'A 5km ride cost $10.50'

# %%
word_tokenize(sent5)
# Out:
# ['I', 'have', 'a', 'ph.d', 'in', 'A.I']

# %%
word_tokenize(sent6)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  '!',
#  'mail',
#  'us',
#  'john.mclean',
#  '@',
#  'examplepetstore.comcom']

# %%
word_tokenize(sent7)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.50']

# %% [markdown]
# 4. Spacy

# %% [markdown]
# Best library for nltk

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
# convert The sentence into document
doc1 = nlp(sent5)
doc2 = nlp(sent6)
doc3 = nlp(sent7)
doc4 = nlp(text)

# %%
for token in doc3:
  print(token)
# Out:
# A
# 5
# km
# ride
# cost
# $
# 10.50

# %%
for token in doc2:
  print(token)
# Out:
# We
# 're
# here
# to
# help
# !
# mail
# us
# john.mclean@examplepetstore.comcom

# %%
dummy = "Lorem Ipsum is simply dummy text of The printing and typesetting industry. Lorem Ipsum has been The industry's standard dummy text ever since The 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also The leap into electronic typesetting, remaining essentially unchanged. It was popularised in The 1960s with The release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

# %%
dummy
# Out:
# "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
sents = sent_tokenize(dummy)

# %%
sents
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry.',
#  "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.",
#  'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.',
#  'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.']

# %%
for sent in sents:
  print(word_tokenize(sent))
# Out:
# ['Lorem', 'Ipsum', 'is', 'simply', 'dummy', 'text', 'of', 'the', 'printing', 'and', 'typesetting', 'industry', '.']
# ['Lorem', 'Ipsum', 'has', 'been', 'the', 'industry', "'s", 'standard', 'dummy', 'text', 'ever', 'since', 'the', '1500s', ',', 'when', 'an', 'unknown', 'printer', 'took', 'a', 'galley', 'of', 'type', 'and', 'scrambled', 'it', 'to', 'make', 'a', 'type', 'specimen', 'book', '.']
# ['It', 'has', 'survived', 'not', 'only', 'five', 'centuries', ',', 'but', 'also', 'the', 'leap', 'into', 'electronic', 'typesetting', ',', 'remaining', 'essentially', 'unchanged', '.']
# ['It', 'was', 'popularised', 'in', 'the', '1960s', 'with', 'the', 'release', 'of', 'Letraset', 'sheets', 'containing', 'Lorem', 'Ipsum', 'passages', ',', 'and', 'more', 'recently', 'with', 'desktop', 'publishing', 'software', 'like', 'Aldus', 'PageMaker', 'including', 'versions', 'of', 'Lorem', 'Ipsum', '.']

# %% [markdown]
# # Stemming

# %% [markdown]
# In![Screenshot 2025-11-10 190313.png](data:image/png;base64,...) grammer, inflection is The modification of a word to express different grammatical categories such as tense,case,voice,aspect,person,number,number,gender and mood

# %% [markdown]
# Stemming = stemming is The process of reducing inflection in words to Their root forms such as mapping a group of words to The same stem even if The stem itself is not a valid word in The Language.

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()
def stem_words(text):
  return " ".join([ps.stem(word) for word in text.split()])

# %%
sample = 'walk walks walking walked'
stem_words(sample)
# Out:
# 'walk walk walk walk'

# %%
text = 'probably my alltime favorite movie a story of selflessness sacrifice and dedication to nobel cause cause but its not preachy or boring it just never gets '
print(text)
# Out:
# probably my alltime favorite movie a story of selflessness sacrifice and dedication to nobel cause cause but its not preachy or boring it just never gets

# %%
stem_words(text)
# Out:
# 'probabl my alltim favorit movi a stori of selfless sacrific and dedic to nobel caus caus but it not preachi or bore it just never get'

# %% [markdown]
# # Lemmatization![Screenshot 2025-11-10 192129.png](data:image/png;base64,...)

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
sentence = "He was running and eating at same time.He has bad habit of swimming after playing long hours in The Sun."
punctuation = "?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuation:
        sentence_words.remove(word)
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word)))
# Out:
# Word                Lemma
# He                  He
# was                 wa
# running             running
# and                 and
# eating              eating
# at                  at
# same                same
# time.He             time.He
# has                 ha
# bad                 bad
# habit               habit
# of                  of
# swimming            swimming
# after               after
# playing             playing
# long                long
# hours               hour
# in                  in
# the                 the
# Sun                 Sun
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
sentence = "He was running and eating at same time.He has bad habit of swimming after playing long hours in The Sun."
punctuation = "?:!.,;"
sentence_words = nltk.word_tokenize(sentence)
for word in sentence_words:
    if word in punctuation:
        sentence_words.remove(word)
sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print("{0:20}{1:20}".format(word,wordnet_lemmatizer.lemmatize(word,pos='v')))
# Out:
# Word                Lemma
# He                  He
# was                 be
# running             run
# and                 and
# eating              eat
# at                  at
# same                same
# time.He             time.He
# has                 have
# bad                 bad
# habit               habit
# of                  of
# swimming            swim
# after               after
# playing             play
# long                long
# hours               hours
# in                  in
# the                 the
# Sun                 Sun
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Assignment

# %% [markdown]
# Creat a Dataset

# %% [markdown]
# Text-preprocessing

# %% [markdown]
# Tmdb api

# %%
import json
import pandas as pd

data = {
   "page":1,
   "results":[{"adult":False,"backdrop_path":"/v8xVDqt8uCul3c3mgx4VpGCwxJC.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":24.4578,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":False,"vote_average":8.711,"vote_count":29197},{"adult":False,"backdrop_path":"/jdHsptJbtalEuVhCV5i7kSC3g0x.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge
backdrop_path":"/jJK3skg06c2iUXgpJg9DTxQhRb4.jpg","genre_ids":[18],"id":3780,"original_language":"ja","original_title":"赤ひげ","overview":"Aspiring to an easy job as personal physician to a wealthy family, Noboru Yasumoto is disappointed when his first post after medical school takes him to a small country clinic under the gruff doctor Red Beard. Yasumoto rebels in numerous ways, but Red Beard proves a wise and patient teacher. He gradually introduces his student to the unglamorous side of the profession, ultimately assigning him to care for a prostitute rescued from a local brothel.","popularity":3.648,"poster_path":"/iYNH3Re0JSypoYaWvZtERUnNaJL.jpg","release_date":"1965-04-03","title":"Red Beard","video":False,"vote_average":8.112,"vote_count":386},{"adult":False,"backdrop_path":"/foFq1RZWQIgFuCQ0nyYccywjFyX.jpg","genre_ids":[18,10749,36],"id":531428,"original_language":"fr","original_title":"Portrait de la jeune fille en feu","overview":"On an isolated island in Brittany at the end of the eighteenth century, a female painter is obliged to paint a wedding portrait of a young woman.","popularity":5.6117,"poster_path":"/2LquGwEhbg3soxSCs9VNyh5VJd9.jpg","release_date":"2019-09-18","title":"Portrait of a Lady on Fire","video":False,"vote_average":8.107,"vote_count":2801}],

   }
# Convert only "results" into dataframe
df = pd.DataFrame(data["results"])
print(df.head())
# Out:
#    adult                     backdrop_path         genre_ids       id  \
# 0  False  /6aoyUbvu0419XLKLIMoH0TkEicH.jpg          [80, 18]      103
# 1  False  /rogeBJK44LtWynOqzMFmEF30T80.jpg  [16, 14, 28, 12]   812225
# 2  False  /o869RihWTdTyBcEZBjz0izvEsVf.jpg         [878, 12]   693134
# 3  False  /3kvS6Ws5usxSk1wIbKZ7YPug2V2.jpg              [18]  1103621
# 4  False  /rlay2M5QYvi6igbGcFjq8jxeusY.jpg      [80, 53, 18]   475557
#
#   original_language      original_title  \
# 0                en         Taxi Driver
# 1                ja  映画 ブラッククローバー 魔法帝の剣
# 2                en      Dune: Part Two
# 3                th             หลานม่า
# 4                en               Joker
#
#                                             overview  popularity  \
# 0  Suffering from insomnia, disturbed loner Travi...     10.1588
# 1  As a lionhearted boy who can't wield magic str...      7.2812
# 2  Follow the mythic journey of Paul Atreides as ...     14.1112
# ...

# %%
df.head(1)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /6aoyUbvu0419XLKLIMoH0TkEicH.jpg  [80, 18]  103                en
#
#   original_title                                           overview  \
# 0    Taxi Driver  Suffering from insomnia, disturbed loner Travi...
#
#    popularity                       poster_path release_date        title  \
# 0     10.1588  /ekstpH614fwDX8DUln1a2Opz0N8.jpg   1976-02-09  Taxi Driver
#
#    video  vote_average  vote_count
# 0  False         8.133       12970

# %%
df.shape
# Out:
# (20, 14)

# %%
df_new = df.drop(['genre_ids','backdrop_path','original_language','popularity','poster_path','release_date','video','vote_average','vote_count','adult','original_title'], axis=1)

# %%
df_new.head(10)
# Out:
#         id                                           overview  \
# 0      103  Suffering from insomnia, disturbed loner Travi...
# 1   812225  As a lionhearted boy who can't wield magic str...
# 2   693134  Follow the mythic journey of Paul Atreides as ...
# 3  1103621  M, a university dropout low on money and luck,...
# 4   475557  During the 1980s, a failed stand-up comedian i...
# 5   823219  A solitary cat, displaced by a great flood, fi...
# 6    20914  Four inseparable friends try to face their mid...
# 7     9702  Based on the True life experiences of poet Jim...
# 8      935  After the insane General Jack D. Ripper initia...
# 9      600  A pragmatic U.S. Marine observes the dehumaniz...
#
#                                                title
# 0                                        Taxi Driver
# 1             Black Clover: Sword of the Wizard King
# 2                                     Dune: Part Two
# 3           How to Make Millions Before Grandma Dies
# ...

# %%
df_new = df_new.drop('id',axis=1)

# %%
df_new.head(10)
# Out:
#                                             overview  \
# 0  Suffering from insomnia, disturbed loner Travi...
# 1  As a lionhearted boy who can't wield magic str...
# 2  Follow the mythic journey of Paul Atreides as ...
# 3  M, a university dropout low on money and luck,...
# 4  During the 1980s, a failed stand-up comedian i...
# 5  A solitary cat, displaced by a great flood, fi...
# 6  Four inseparable friends try to face their mid...
# 7  Based on the True life experiences of poet Jim...
# 8  After the insane General Jack D. Ripper initia...
# 9  A pragmatic U.S. Marine observes the dehumaniz...
#
#                                                title
# 0                                        Taxi Driver
# 1             Black Clover: Sword of the Wizard King
# 2                                     Dune: Part Two
# 3           How to Make Millions Before Grandma Dies
# 4                                              Joker
# 5                                               Flow
# ...

# %%
# Removing html tag
sample_text ='<header ><div class="Top_name"><b>Tagore Library</b></div><div class="header1">Home</div><div class="header2">About</div><div class="header3">Contact</div></header>'

# %%
sample_text
# Out:
# '<header ><div class="Top_name"><b>Tagore Library</b></div><div class="header1">Home</div><div class="header2">About</div><div class="header3">Contact</div></header>'

# %%
import re
def striphtml(df_new):
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'','overview')

# %%
# Removing Punctuation
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punc(df_new):
  for char in exclude:
    overview = overview.replace(char,'')
  return overview

# %%
# removing stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
  new_text = []
  for word in text():
    if word in stopwords.words('english'):
      new_text.append(' ')
    else:
      new_text.append(word)
    x = new_text[:]
    new_text.clear()
    return " ".join(x)

# %%
df_new['overview']
# Out:
# 0     Suffering from insomnia, disturbed loner Travi...
# 1     As a lionhearted boy who can't wield magic str...
# 2     Follow the mythic journey of Paul Atreides as ...
# 3     M, a university dropout low on money and luck,...
# 4     During the 1980s, a failed stand-up comedian i...
# 5     A solitary cat, displaced by a great flood, fi...
# 6     Four inseparable friends try to face their mid...
# 7     Based on the True life experiences of poet Jim...
# 8     After the insane General Jack D. Ripper initia...
# 9     A pragmatic U.S. Marine observes the dehumaniz...
# 10    Guido Anselmi, a film director, finds himself ...
# 11    Yuta Okkotsu is a nervous high school student ...
# 12    A botched robbery indicates a police informant...
# 13    Violet Evergarden comes to a private women's a...
# 14    Near a gray and unnamed city is the Zone, a pl...
# 15    I Corti ("Shorts") by Aldo, Giovanni & Giacomo...
# 16    While trying to free her sister from Fahai's c...
# ...

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop = set(stopwords.words('english'))

# %%
text = df['overview']

# %%
df['overview'] = df['overview'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop]))

# %%
df['overview'].head(10)
# Out:
# 0    Suffering insomnia, disturbed loner Travis Bic...
# 1    lionhearted boy can't wield magic strives titl...
# 2    Follow mythic journey Paul Atreides unites Cha...
# 3    M, university dropout low money luck, voluntee...
# 4    1980s, failed stand-up comedian driven insane ...
# 5    solitary cat, displaced great flood, finds ref...
# 6    Four inseparable friends try face midlife cris...
# 7    Based True life experiences poet Jimmy Santiag...
# 8    insane General Jack D. Ripper initiates nuclea...
# 9    pragmatic U.S. Marine observes dehumanizing ef...
# Name: overview, dtype: object

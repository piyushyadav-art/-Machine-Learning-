# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushyadav-art/-Machine-Learning-/blob/main/openCV_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of openCV

# %% [markdown]
# For Reading/Loading Image

# %% [markdown]
# image = cv2.imread("filename.jpg",flag)
# flag =: 1-->color, 2 --> grayscale, 3 --> unchanged

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')

if image is None:
   print("Error: Image not found.")
else:
  print("Image loaded successfully")
# Out:
# Error: Image not found.

# %% [markdown]
# **For displaying Image**
# 1. imshow
# 2. waitkey
# 3. destroy

# %%
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')

if image is not None:
  cv2_imshow(image) # Changed cv2.imshow to cv2_imshow
  cv2.waitKey(0)
  cv2.destroyAllWindows()
else:
  print("Image could not found")
# Out:
# Image could not found

# %% [markdown]
# **For saving image**
# cv2.imwrite("give_name",image)

# %%
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')

if image is not None:
  success = cv2.imwrite("Output_python.png",image)
  if success:
    print("Image saved successfully")
  else:
    print("Error: Failed to save the image")
else:
  print("Image could not found")
# Out:
# Image could not found

# %% [markdown]
# **4. image dimension/Shape**
# 1. Height
# 2. Width
# 3. color channel

# %% [markdown]
# (height,width,color_channel);
# channel -->
# 1. 3->RGB
# 2. if not give then or mission then gray screen

# %%
import cv2

image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
if image is not None:
  height,width,channels = image.shape
  print(f"Image Loaded:\nHeight : {height}:\nWidth : {width}\nChannels : {channels}")

else:
  print("Image could not found")
# Out:
# Image could not found

# %% [markdown]
# **Grayscale conversion cutdown**
# colorfull image ---> Grayscale image

# %%
# gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')

if image is not None:
  gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
  cv2_imshow(gray)
  cv2.waitKey(0)
  cv2.destroyAllWindows()


else:
  print("Image could not found")
# Out:
# Image could not found

# %% [markdown]
# Q1. Load(user input) -> Graysale -> show -> Save(print file name save successfully)

# %% [markdown]
# #Image Transformations & Manipulation

# %% [markdown]
# #Phase 1:

# %% [markdown]
# **Resizing & and scaling Images - cv2.resize()**

# %% [markdown]
# resized = cv2.resize(src, dsize, fx, fy, interpolation)
# 1. scr -> Original name of image
# 2. dsize -> in pixel's ->(width,height)
# 3. fx & fy ->scale factor ,interpolation( both optional)

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')

if image is None:
  print("Error: Image not found.")
else:
  print("Image loaded successfully")
  resized = cv2.resize(image,(300,300))

  cv2_imshow(image)
  cv2_imshow(resized)
  cv2.imwrite("Resized_output.png",resized)

  cv2.waitKey(0)
  cv2.destroyAllWindows()
# Out:
# Error: Image not found.

# %% [markdown]
# **Cropping Image using Slicing in openCV**

# %% [markdown]
# cropped_image = image[startY:endY,startX:endX]

# %%
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
cropped = image[50:350,150:300]
cv2_imshow(image)
cv2_imshow(cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()
print("Image is croped successfully")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4223505274.py in <cell line: 0>()
#       1 image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
# ----> 2 cropped = image[50:350,150:300]
#       3 cv2_imshow(image)
#       4 cv2_imshow(cropped)
#       5 cv2.waitKey(0)
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# **Image rotation and flipping**

# %% [markdown]
# M = cv2.getRotationMatrix2D(center, angle, scale)
# Center point =(width//2, height//2)
# rotated_image = cv2.warpAffine(image, M, (width,height)):

# %%
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
h,w = image.shape[:2]
print(h,w)
center = (w//2,h//2)
print(center)
M = cv2.getRotationMatrix2D(center,90,1.0)
rotated = cv2.warpAffine(image,M,(w, h))

cv2_imshow(image)
cv2_imshow(rotated)
cv2.waitKey(0)
cv2.destroyAllWindows()
print("Image is rotated successfully")

# %% [markdown]
# filliped = cv2.flip(image,flipcode)
# image = original image
# flipcode:                              0. vertically top to bottom
# 1. horizntally left to right
# -1. horizontal to verticall

# %%
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
flipped_horizontal = cv2.flip(image,1)
filliped_vertical = cv2.flip(image,0)
flipped_both = cv2.flip(image,-1)

cv2_imshow(image)
print("Original Image")
cv2_imshow(flipped_horizontal)
print("flipped horizontal")
cv2_imshow(filliped_vertical)
print("flipped vertically")
cv2_imshow(flipped_both)
print("flipped both")
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #Phase 2:

# %% [markdown]
# **Basic Image drawing Techniques**

# %% [markdown]
# **Drawing a line**

# %% [markdown]
# cv2.line(img,pt1,pt2,color,thickness)

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
pt1 = (100,60)
pt2 = (400,60)
color = (255,0,0)
thickness = 4
cv2.line(image, pt1,pt2, color,thickness)
cv2_imshow( image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# **Drawing a  rectangle**
# cv2.rectangle(img,plt1,plt2,color,thickness)

# %% [markdown]
# plt1 --> Top left corner
# plt2 --> Bottom right corner

# %%
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
# pt1 = (100,60)
# pt2 = (400,200)
# color = (0,0,255)
# thickness = 4
cv2.rectangle(image, pt1=(110,70),pt2=(410,190),color=(0,0,255),thickness=4)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# **For Drawing circleA **
# image = cv2.circle(image,center,radius,color,thiclness) if thickness = -1 then circle fill with color

# %%
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
# pt1 = (100,60)
# pt2 = (400,200)
# color = (0,0,255)
# thickness = 4
cv2.circle(image, (150,150),100,(255,0,0),-1)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ***For Adding text***
# cv2.putText(img, text,org,font,fontScale,color,thickness)

# %% [markdown]
# text -> Text written by coder
# org -> (x,y)

# %%
import cv2
image = cv2.imread('/content/793bb0d8845f9a44f922b1903fb94c58.jpg')
cv2.putText(image, "Hello Python Programmer",(1,200),cv2.FONT_HERSHEY_SIMPLEX,1.15,(255,0,0),4)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Home work 2:14:26

# %% [markdown]
# # Video Processing Workflow

# %%
import cv2


cap = cv2.VideoCapture(0)

while True:
  ret, frame = cap.read() # ret =True/False, Frame = image

  if not ret:
    print("Could not read frame")
    break

  cv2_imshow(frame)
  if cv2.waitKey(1) & 0xFF == ord('q'):
    print("Quitting...")
    break
cap.release()
cv2.destroyAllWindows()
# Out:
# Could not read frame

# %%
# Step 1: Imports
from IPython.display import Javascript, display
from google.colab.output import eval_js
import cv2
import numpy as np
import base64

# Step 2: JavaScript to open camera in browser
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
      async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = '📸 Capture';
        div.appendChild(capture);
        document.body.appendChild(div);
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        const video = document.createElement('video');
        video.style.display = 'block';
        video.srcObject = stream;
        await video.play();
        google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
        await new Promise((resolve) => capture.onclick = resolve);
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getVideoTracks()[0].stop();
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
      }
    ''')
    display(js)
    data = eval_js('takePhoto({})'.format(quality))
    binary = base64.b64decode(data.split(',')[1])
    with open(filename, 'wb') as f:
        f.write(binary)
    return filename

# Step 3: Capture photo
filename = take_photo()
print("Saved to", filename)

# Step 4: Load and show image using OpenCV
img = cv2.imread(filename)
cv2_imshow(img)  # Works in Colab
# Out:
# Saved to photo.jpg
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
# Out:
# 1

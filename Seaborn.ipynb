# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushyadav-art/-Machine-Learning-/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Visualisation Library's

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Note-Seaborn has some built-in datasets

# %%
# total bill vs tip dataset
tips = sns.load_dataset("tips")

# %%
tips
